# %%
import numpy as np
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import r2_score, mean_squared_error
import pickle

# %%
X = np.load("../data/X_train_scaled.npy", allow_pickle=True)
y = np.load("../data/y_train_scaled.npy", allow_pickle=True)

# %%
print("X shape:", X.shape)
print("y shape:", y.shape)
# Out:
# X shape: (3104579, 26)
# y shape: (3104579, 1)

# %%
rf = RandomForestRegressor()

# %%
param_grid = {
    "bootstrap": [True, False],
    "max_depth": [2,6,12],
    "n_estimators": [5, 50],
}

# %%
grid_search = GridSearchCV(
    rf,
    param_grid,
    scoring="neg_mean_squared_error",
    cv=10,
    verbose=10
)

# %%
y = y.ravel()

# %%
np.random.seed(2907)
grid_search.fit(X, y)
# Out:
# Fitting 10 folds for each of 12 candidates, totalling 120 fits
# [CV 1/10; 1/12] START bootstrap=True, max_depth=2, n_estimators=5...............
# [CV 1/10; 1/12] END bootstrap=True, max_depth=2, n_estimators=5;, score=-0.986 total time=  25.7s
# [CV 2/10; 1/12] START bootstrap=True, max_depth=2, n_estimators=5...............
# [CV 2/10; 1/12] END bootstrap=True, max_depth=2, n_estimators=5;, score=-0.777 total time=  26.1s
# [CV 3/10; 1/12] START bootstrap=True, max_depth=2, n_estimators=5...............
# [CV 3/10; 1/12] END bootstrap=True, max_depth=2, n_estimators=5;, score=-0.663 total time=  26.1s
# [CV 4/10; 1/12] START bootstrap=True, max_depth=2, n_estimators=5...............
# [CV 4/10; 1/12] END bootstrap=True, max_depth=2, n_estimators=5;, score=-0.607 total time=  26.0s
# [CV 5/10; 1/12] START bootstrap=True, max_depth=2, n_estimators=5...............
# [CV 5/10; 1/12] END bootstrap=True, max_depth=2, n_estimators=5;, score=-0.728 total time=  25.8s
# [CV 6/10; 1/12] START bootstrap=True, max_depth=2, n_estimators=5...............
# [CV 6/10; 1/12] END bootstrap=True, max_depth=2, n_estimators=5;, score=-1.011 total time=  25.4s
# [CV 7/10; 1/12] START bootstrap=True, max_depth=2, n_estimators=5...............
# [CV 7/10; 1/12] END bootstrap=True, max_depth=2, n_estimators=5;, score=-0.761 total time=  26.3s
# [CV 8/10; 1/12] START bootstrap=True, max_depth=2, n_estimators=5...............
# [CV 8/10; 1/12] END bootstrap=True, max_depth=2, n_estimators=5;, score=-0.920 total time=  26.4s
# [CV 9/10; 1/12] START bootstrap=True, max_depth=2, n_estimators=5...............
# [CV 9/10; 1/12] END bootstrap=True, max_depth=2, n_estimators=5;, score=-0.964 total time=  25.9s
# [CV 10/10; 1/12] START bootstrap=True, max_depth=2, n_estimators=5..............
# [CV 10/10; 1/12] END bootstrap=True, max_depth=2, n_estimators=5;, score=-0.945 total time=  26.1s
# [CV 1/10; 2/12] START bootstrap=True, max_depth=2, n_estimators=50..............
# [CV 1/10; 2/12] END bootstrap=True, max_depth=2, n_estimators=50;, score=-0.986 total time= 4.2min
# [CV 2/10; 2/12] START bootstrap=True, max_depth=2, n_estimators=50..............
# [CV 2/10; 2/12] END bootstrap=True, max_depth=2, n_estimators=50;, score=-0.777 total time= 4.2min
# [CV 3/10; 2/12] START bootstrap=True, max_depth=2, n_estimators=50..............
# [CV 3/10; 2/12] END bootstrap=True, max_depth=2, n_estimators=50;, score=-0.663 total time= 4.2min
# [CV 4/10; 2/12] START bootstrap=True, max_depth=2, n_estimators=50..............
# [CV 4/10; 2/12] END bootstrap=True, max_depth=2, n_estimators=50;, score=-0.606 total time= 4.3min
# [CV 5/10; 2/12] START bootstrap=True, max_depth=2, n_estimators=50..............
# [CV 5/10; 2/12] END bootstrap=True, max_depth=2, n_estimators=50;, score=-0.728 total time= 4.3min
# [CV 6/10; 2/12] START bootstrap=True, max_depth=2, n_estimators=50..............
# [CV 6/10; 2/12] END bootstrap=True, max_depth=2, n_estimators=50;, score=-1.011 total time= 4.2min
# [CV 7/10; 2/12] START bootstrap=True, max_depth=2, n_estimators=50..............
# [CV 7/10; 2/12] END bootstrap=True, max_depth=2, n_estimators=50;, score=-0.761 total time= 4.1min
# [CV 8/10; 2/12] START bootstrap=True, max_depth=2, n_estimators=50..............
# [CV 8/10; 2/12] END bootstrap=True, max_depth=2, n_estimators=50;, score=-0.920 total time= 3.9min
# [CV 9/10; 2/12] START bootstrap=True, max_depth=2, n_estimators=50..............
# [CV 9/10; 2/12] END bootstrap=True, max_depth=2, n_estimators=50;, score=-0.964 total time= 3.9min
# [CV 10/10; 2/12] START bootstrap=True, max_depth=2, n_estimators=50.............
# [CV 10/10; 2/12] END bootstrap=True, max_depth=2, n_estimators=50;, score=-0.945 total time= 4.0min
# [CV 1/10; 3/12] START bootstrap=True, max_depth=6, n_estimators=5...............
# [CV 1/10; 3/12] END bootstrap=True, max_depth=6, n_estimators=5;, score=-0.677 total time= 1.1min
# [CV 2/10; 3/12] START bootstrap=True, max_depth=6, n_estimators=5...............
# [CV 2/10; 3/12] END bootstrap=True, max_depth=6, n_estimators=5;, score=-0.493 total time= 1.1min
# [CV 3/10; 3/12] START bootstrap=True, max_depth=6, n_estimators=5...............
# [CV 3/10; 3/12] END bootstrap=True, max_depth=6, n_estimators=5;, score=-0.349 total time= 1.1min
# [CV 4/10; 3/12] START bootstrap=True, max_depth=6, n_estimators=5...............
# [CV 4/10; 3/12] END bootstrap=True, max_depth=6, n_estimators=5;, score=-0.365 total time= 1.1min
# [CV 5/10; 3/12] START bootstrap=True, max_depth=6, n_estimators=5...............
# [CV 5/10; 3/12] END bootstrap=True, max_depth=6, n_estimators=5;, score=-0.443 total time= 1.1min
# [CV 6/10; 3/12] START bootstrap=True, max_depth=6, n_estimators=5...............
# [CV 6/10; 3/12] END bootstrap=True, max_depth=6, n_estimators=5;, score=-0.650 total time= 1.1min
# [CV 7/10; 3/12] START bootstrap=True, max_depth=6, n_estimators=5...............
# [CV 7/10; 3/12] END bootstrap=True, max_depth=6, n_estimators=5;, score=-0.493 total time= 1.1min
# [CV 8/10; 3/12] START bootstrap=True, max_depth=6, n_estimators=5...............
# [CV 8/10; 3/12] END bootstrap=True, max_depth=6, n_estimators=5;, score=-0.607 total time= 1.1min
# [CV 9/10; 3/12] START bootstrap=True, max_depth=6, n_estimators=5...............
# [CV 9/10; 3/12] END bootstrap=True, max_depth=6, n_estimators=5;, score=-0.647 total time= 1.1min
# [CV 10/10; 3/12] START bootstrap=True, max_depth=6, n_estimators=5..............
# [CV 10/10; 3/12] END bootstrap=True, max_depth=6, n_estimators=5;, score=-0.654 total time= 1.1min
# [CV 1/10; 4/12] START bootstrap=True, max_depth=6, n_estimators=50..............
# [CV 1/10; 4/12] END bootstrap=True, max_depth=6, n_estimators=50;, score=-0.678 total time=10.6min
# [CV 2/10; 4/12] START bootstrap=True, max_depth=6, n_estimators=50..............
# [CV 2/10; 4/12] END bootstrap=True, max_depth=6, n_estimators=50;, score=-0.495 total time=10.8min
# [CV 3/10; 4/12] START bootstrap=True, max_depth=6, n_estimators=50..............
# [CV 3/10; 4/12] END bootstrap=True, max_depth=6, n_estimators=50;, score=-0.345 total time=10.7min
# [CV 4/10; 4/12] START bootstrap=True, max_depth=6, n_estimators=50..............
# [CV 4/10; 4/12] END bootstrap=True, max_depth=6, n_estimators=50;, score=-0.360 total time=10.9min
# [CV 5/10; 4/12] START bootstrap=True, max_depth=6, n_estimators=50..............
# [CV 5/10; 4/12] END bootstrap=True, max_depth=6, n_estimators=50;, score=-0.442 total time=10.7min
# [CV 6/10; 4/12] START bootstrap=True, max_depth=6, n_estimators=50..............
# [CV 6/10; 4/12] END bootstrap=True, max_depth=6, n_estimators=50;, score=-0.642 total time=10.7min
# [CV 7/10; 4/12] START bootstrap=True, max_depth=6, n_estimators=50..............
# [CV 7/10; 4/12] END bootstrap=True, max_depth=6, n_estimators=50;, score=-0.499 total time=10.6min
# [CV 8/10; 4/12] START bootstrap=True, max_depth=6, n_estimators=50..............
# [CV 8/10; 4/12] END bootstrap=True, max_depth=6, n_estimators=50;, score=-0.608 total time=10.8min
# [CV 9/10; 4/12] START bootstrap=True, max_depth=6, n_estimators=50..............
# [CV 9/10; 4/12] END bootstrap=True, max_depth=6, n_estimators=50;, score=-0.653 total time=10.8min
# [CV 10/10; 4/12] START bootstrap=True, max_depth=6, n_estimators=50.............
# [CV 10/10; 4/12] END bootstrap=True, max_depth=6, n_estimators=50;, score=-0.649 total time=10.7min
# [CV 1/10; 5/12] START bootstrap=True, max_depth=12, n_estimators=5..............
# [CV 1/10; 5/12] END bootstrap=True, max_depth=12, n_estimators=5;, score=-0.424 total time= 1.7min
# [CV 2/10; 5/12] START bootstrap=True, max_depth=12, n_estimators=5..............
# [CV 2/10; 5/12] END bootstrap=True, max_depth=12, n_estimators=5;, score=-0.285 total time= 1.7min
# [CV 3/10; 5/12] START bootstrap=True, max_depth=12, n_estimators=5..............
# [CV 3/10; 5/12] END bootstrap=True, max_depth=12, n_estimators=5;, score=-0.202 total time= 1.7min
# [CV 4/10; 5/12] START bootstrap=True, max_depth=12, n_estimators=5..............
# [CV 4/10; 5/12] END bootstrap=True, max_depth=12, n_estimators=5;, score=-0.211 total time= 1.7min
# [CV 5/10; 5/12] START bootstrap=True, max_depth=12, n_estimators=5..............
# [CV 5/10; 5/12] END bootstrap=True, max_depth=12, n_estimators=5;, score=-0.265 total time= 1.7min
# [CV 6/10; 5/12] START bootstrap=True, max_depth=12, n_estimators=5..............
# [CV 6/10; 5/12] END bootstrap=True, max_depth=12, n_estimators=5;, score=-0.374 total time= 1.7min
# [CV 7/10; 5/12] START bootstrap=True, max_depth=12, n_estimators=5..............
# [CV 7/10; 5/12] END bootstrap=True, max_depth=12, n_estimators=5;, score=-0.304 total time= 1.7min
# [CV 8/10; 5/12] START bootstrap=True, max_depth=12, n_estimators=5..............
# [CV 8/10; 5/12] END bootstrap=True, max_depth=12, n_estimators=5;, score=-0.358 total time= 1.7min
# [CV 9/10; 5/12] START bootstrap=True, max_depth=12, n_estimators=5..............
# [CV 9/10; 5/12] END bootstrap=True, max_depth=12, n_estimators=5;, score=-0.389 total time= 1.7min
# [CV 10/10; 5/12] START bootstrap=True, max_depth=12, n_estimators=5.............
# [CV 10/10; 5/12] END bootstrap=True, max_depth=12, n_estimators=5;, score=-0.408 total time= 1.7min
# [CV 1/10; 6/12] START bootstrap=True, max_depth=12, n_estimators=50.............
# [CV 1/10; 6/12] END bootstrap=True, max_depth=12, n_estimators=50;, score=-0.419 total time=17.0min
# [CV 2/10; 6/12] START bootstrap=True, max_depth=12, n_estimators=50.............
# [CV 2/10; 6/12] END bootstrap=True, max_depth=12, n_estimators=50;, score=-0.283 total time=17.0min
# [CV 3/10; 6/12] START bootstrap=True, max_depth=12, n_estimators=50.............
# [CV 3/10; 6/12] END bootstrap=True, max_depth=12, n_estimators=50;, score=-0.200 total time=16.9min
# [CV 4/10; 6/12] START bootstrap=True, max_depth=12, n_estimators=50.............
# [CV 4/10; 6/12] END bootstrap=True, max_depth=12, n_estimators=50;, score=-0.207 total time=17.1min
# [CV 5/10; 6/12] START bootstrap=True, max_depth=12, n_estimators=50.............
# [CV 5/10; 6/12] END bootstrap=True, max_depth=12, n_estimators=50;, score=-0.260 total time=17.2min
# [CV 6/10; 6/12] START bootstrap=True, max_depth=12, n_estimators=50.............
# [CV 6/10; 6/12] END bootstrap=True, max_depth=12, n_estimators=50;, score=-0.369 total time=17.1min
# [CV 7/10; 6/12] START bootstrap=True, max_depth=12, n_estimators=50.............
# [CV 7/10; 6/12] END bootstrap=True, max_depth=12, n_estimators=50;, score=-0.305 total time=17.0min
# [CV 8/10; 6/12] START bootstrap=True, max_depth=12, n_estimators=50.............
# [CV 8/10; 6/12] END bootstrap=True, max_depth=12, n_estimators=50;, score=-0.349 total time=17.0min
# [CV 9/10; 6/12] START bootstrap=True, max_depth=12, n_estimators=50.............
# [CV 9/10; 6/12] END bootstrap=True, max_depth=12, n_estimators=50;, score=-0.378 total time=17.1min
# [CV 10/10; 6/12] START bootstrap=True, max_depth=12, n_estimators=50............
# [CV 10/10; 6/12] END bootstrap=True, max_depth=12, n_estimators=50;, score=-0.402 total time=17.0min
# [CV 1/10; 7/12] START bootstrap=False, max_depth=2, n_estimators=5..............
# [CV 1/10; 7/12] END bootstrap=False, max_depth=2, n_estimators=5;, score=-0.986 total time=  34.2s
# [CV 2/10; 7/12] START bootstrap=False, max_depth=2, n_estimators=5..............
# [CV 2/10; 7/12] END bootstrap=False, max_depth=2, n_estimators=5;, score=-0.777 total time=  34.8s
# [CV 3/10; 7/12] START bootstrap=False, max_depth=2, n_estimators=5..............
# [CV 3/10; 7/12] END bootstrap=False, max_depth=2, n_estimators=5;, score=-0.663 total time=  34.5s
# [CV 4/10; 7/12] START bootstrap=False, max_depth=2, n_estimators=5..............
# [CV 4/10; 7/12] END bootstrap=False, max_depth=2, n_estimators=5;, score=-0.606 total time=  35.5s
# [CV 5/10; 7/12] START bootstrap=False, max_depth=2, n_estimators=5..............
# [CV 5/10; 7/12] END bootstrap=False, max_depth=2, n_estimators=5;, score=-0.728 total time=  35.2s
# [CV 6/10; 7/12] START bootstrap=False, max_depth=2, n_estimators=5..............
# [CV 6/10; 7/12] END bootstrap=False, max_depth=2, n_estimators=5;, score=-1.011 total time=  34.3s
# [CV 7/10; 7/12] START bootstrap=False, max_depth=2, n_estimators=5..............
# [CV 7/10; 7/12] END bootstrap=False, max_depth=2, n_estimators=5;, score=-0.761 total time=  35.0s
# [CV 8/10; 7/12] START bootstrap=False, max_depth=2, n_estimators=5..............
# [CV 8/10; 7/12] END bootstrap=False, max_depth=2, n_estimators=5;, score=-0.920 total time=  34.7s
# [CV 9/10; 7/12] START bootstrap=False, max_depth=2, n_estimators=5..............
# [CV 9/10; 7/12] END bootstrap=False, max_depth=2, n_estimators=5;, score=-0.964 total time=  34.6s
# [CV 10/10; 7/12] START bootstrap=False, max_depth=2, n_estimators=5.............
# [CV 10/10; 7/12] END bootstrap=False, max_depth=2, n_estimators=5;, score=-0.945 total time=  35.0s
# [CV 1/10; 8/12] START bootstrap=False, max_depth=2, n_estimators=50.............
# [CV 1/10; 8/12] END bootstrap=False, max_depth=2, n_estimators=50;, score=-0.986 total time= 5.7min
# [CV 2/10; 8/12] START bootstrap=False, max_depth=2, n_estimators=50.............
# [CV 2/10; 8/12] END bootstrap=False, max_depth=2, n_estimators=50;, score=-0.777 total time= 5.7min
# [CV 3/10; 8/12] START bootstrap=False, max_depth=2, n_estimators=50.............
# [CV 3/10; 8/12] END bootstrap=False, max_depth=2, n_estimators=50;, score=-0.663 total time= 5.7min
# [CV 4/10; 8/12] START bootstrap=False, max_depth=2, n_estimators=50.............
# [CV 4/10; 8/12] END bootstrap=False, max_depth=2, n_estimators=50;, score=-0.606 total time= 5.8min
# [CV 5/10; 8/12] START bootstrap=False, max_depth=2, n_estimators=50.............
# [CV 5/10; 8/12] END bootstrap=False, max_depth=2, n_estimators=50;, score=-0.728 total time= 5.7min
# [CV 6/10; 8/12] START bootstrap=False, max_depth=2, n_estimators=50.............
# [CV 6/10; 8/12] END bootstrap=False, max_depth=2, n_estimators=50;, score=-1.011 total time= 5.7min
# [CV 7/10; 8/12] START bootstrap=False, max_depth=2, n_estimators=50.............
# [CV 7/10; 8/12] END bootstrap=False, max_depth=2, n_estimators=50;, score=-0.761 total time= 5.8min
# [CV 8/10; 8/12] START bootstrap=False, max_depth=2, n_estimators=50.............
# [CV 8/10; 8/12] END bootstrap=False, max_depth=2, n_estimators=50;, score=-0.920 total time= 5.7min
# [CV 9/10; 8/12] START bootstrap=False, max_depth=2, n_estimators=50.............
# [CV 9/10; 8/12] END bootstrap=False, max_depth=2, n_estimators=50;, score=-0.964 total time= 5.7min
# [CV 10/10; 8/12] START bootstrap=False, max_depth=2, n_estimators=50............
# [CV 10/10; 8/12] END bootstrap=False, max_depth=2, n_estimators=50;, score=-0.945 total time= 5.7min
# [CV 1/10; 9/12] START bootstrap=False, max_depth=6, n_estimators=5..............
# [CV 1/10; 9/12] END bootstrap=False, max_depth=6, n_estimators=5;, score=-0.692 total time= 1.6min
# [CV 2/10; 9/12] START bootstrap=False, max_depth=6, n_estimators=5..............
# [CV 2/10; 9/12] END bootstrap=False, max_depth=6, n_estimators=5;, score=-0.504 total time= 1.6min
# [CV 3/10; 9/12] START bootstrap=False, max_depth=6, n_estimators=5..............
# [CV 3/10; 9/12] END bootstrap=False, max_depth=6, n_estimators=5;, score=-0.364 total time= 1.6min
# [CV 4/10; 9/12] START bootstrap=False, max_depth=6, n_estimators=5..............
# [CV 4/10; 9/12] END bootstrap=False, max_depth=6, n_estimators=5;, score=-0.370 total time= 1.6min
# [CV 5/10; 9/12] START bootstrap=False, max_depth=6, n_estimators=5..............
# [CV 5/10; 9/12] END bootstrap=False, max_depth=6, n_estimators=5;, score=-0.448 total time= 1.6min
# [CV 6/10; 9/12] START bootstrap=False, max_depth=6, n_estimators=5..............
# [CV 6/10; 9/12] END bootstrap=False, max_depth=6, n_estimators=5;, score=-0.666 total time= 1.6min
# [CV 7/10; 9/12] START bootstrap=False, max_depth=6, n_estimators=5..............
# [CV 7/10; 9/12] END bootstrap=False, max_depth=6, n_estimators=5;, score=-0.507 total time= 1.6min
# [CV 8/10; 9/12] START bootstrap=False, max_depth=6, n_estimators=5..............
# [CV 8/10; 9/12] END bootstrap=False, max_depth=6, n_estimators=5;, score=-0.624 total time= 1.6min
# [CV 9/10; 9/12] START bootstrap=False, max_depth=6, n_estimators=5..............
# [CV 9/10; 9/12] END bootstrap=False, max_depth=6, n_estimators=5;, score=-0.674 total time= 1.6min
# [CV 10/10; 9/12] START bootstrap=False, max_depth=6, n_estimators=5.............
# [CV 10/10; 9/12] END bootstrap=False, max_depth=6, n_estimators=5;, score=-0.672 total time= 1.6min
# [CV 1/10; 10/12] START bootstrap=False, max_depth=6, n_estimators=50............
# [CV 1/10; 10/12] END bootstrap=False, max_depth=6, n_estimators=50;, score=-0.692 total time=16.0min
# [CV 2/10; 10/12] START bootstrap=False, max_depth=6, n_estimators=50............
# [CV 2/10; 10/12] END bootstrap=False, max_depth=6, n_estimators=50;, score=-0.504 total time=16.1min
# [CV 3/10; 10/12] START bootstrap=False, max_depth=6, n_estimators=50............
# [CV 3/10; 10/12] END bootstrap=False, max_depth=6, n_estimators=50;, score=-0.364 total time=16.0min
# [CV 4/10; 10/12] START bootstrap=False, max_depth=6, n_estimators=50............
# [CV 4/10; 10/12] END bootstrap=False, max_depth=6, n_estimators=50;, score=-0.370 total time=16.1min
# [CV 5/10; 10/12] START bootstrap=False, max_depth=6, n_estimators=50............
# [CV 5/10; 10/12] END bootstrap=False, max_depth=6, n_estimators=50;, score=-0.448 total time=16.2min
# [CV 6/10; 10/12] START bootstrap=False, max_depth=6, n_estimators=50............
# [CV 6/10; 10/12] END bootstrap=False, max_depth=6, n_estimators=50;, score=-0.666 total time=16.0min
# [CV 7/10; 10/12] START bootstrap=False, max_depth=6, n_estimators=50............
# [CV 7/10; 10/12] END bootstrap=False, max_depth=6, n_estimators=50;, score=-0.507 total time=15.9min
# [CV 8/10; 10/12] START bootstrap=False, max_depth=6, n_estimators=50............
# [CV 8/10; 10/12] END bootstrap=False, max_depth=6, n_estimators=50;, score=-0.624 total time=16.0min
# [CV 9/10; 10/12] START bootstrap=False, max_depth=6, n_estimators=50............
# [CV 9/10; 10/12] END bootstrap=False, max_depth=6, n_estimators=50;, score=-0.674 total time=16.0min
# [CV 10/10; 10/12] START bootstrap=False, max_depth=6, n_estimators=50...........
# [CV 10/10; 10/12] END bootstrap=False, max_depth=6, n_estimators=50;, score=-0.672 total time=16.1min
# [CV 1/10; 11/12] START bootstrap=False, max_depth=12, n_estimators=5............
# [CV 1/10; 11/12] END bootstrap=False, max_depth=12, n_estimators=5;, score=-0.448 total time= 2.6min
# [CV 2/10; 11/12] START bootstrap=False, max_depth=12, n_estimators=5............
# [CV 2/10; 11/12] END bootstrap=False, max_depth=12, n_estimators=5;, score=-0.306 total time= 2.6min
# [CV 3/10; 11/12] START bootstrap=False, max_depth=12, n_estimators=5............
# [CV 3/10; 11/12] END bootstrap=False, max_depth=12, n_estimators=5;, score=-0.214 total time= 2.6min
# [CV 4/10; 11/12] START bootstrap=False, max_depth=12, n_estimators=5............
# [CV 4/10; 11/12] END bootstrap=False, max_depth=12, n_estimators=5;, score=-0.220 total time= 2.6min
# [CV 5/10; 11/12] START bootstrap=False, max_depth=12, n_estimators=5............
# [CV 5/10; 11/12] END bootstrap=False, max_depth=12, n_estimators=5;, score=-0.277 total time= 2.6min
# [CV 6/10; 11/12] START bootstrap=False, max_depth=12, n_estimators=5............
# [CV 6/10; 11/12] END bootstrap=False, max_depth=12, n_estimators=5;, score=-0.409 total time= 2.6min
# [CV 7/10; 11/12] START bootstrap=False, max_depth=12, n_estimators=5............
# [CV 7/10; 11/12] END bootstrap=False, max_depth=12, n_estimators=5;, score=-0.326 total time= 2.6min
# [CV 8/10; 11/12] START bootstrap=False, max_depth=12, n_estimators=5............
# [CV 8/10; 11/12] END bootstrap=False, max_depth=12, n_estimators=5;, score=-0.382 total time= 2.6min
# [CV 9/10; 11/12] START bootstrap=False, max_depth=12, n_estimators=5............
# [CV 9/10; 11/12] END bootstrap=False, max_depth=12, n_estimators=5;, score=-0.422 total time= 2.6min
# [CV 10/10; 11/12] START bootstrap=False, max_depth=12, n_estimators=5...........
# [CV 10/10; 11/12] END bootstrap=False, max_depth=12, n_estimators=5;, score=-0.441 total time= 2.6min
# [CV 1/10; 12/12] START bootstrap=False, max_depth=12, n_estimators=50...........
# [CV 1/10; 12/12] END bootstrap=False, max_depth=12, n_estimators=50;, score=-0.448 total time=25.9min
# [CV 2/10; 12/12] START bootstrap=False, max_depth=12, n_estimators=50...........
# [CV 2/10; 12/12] END bootstrap=False, max_depth=12, n_estimators=50;, score=-0.306 total time=26.3min
# [CV 3/10; 12/12] START bootstrap=False, max_depth=12, n_estimators=50...........
# [CV 3/10; 12/12] END bootstrap=False, max_depth=12, n_estimators=50;, score=-0.214 total time=26.4min
# [CV 4/10; 12/12] START bootstrap=False, max_depth=12, n_estimators=50...........
# [CV 4/10; 12/12] END bootstrap=False, max_depth=12, n_estimators=50;, score=-0.220 total time=26.2min
# [CV 5/10; 12/12] START bootstrap=False, max_depth=12, n_estimators=50...........
# [CV 5/10; 12/12] END bootstrap=False, max_depth=12, n_estimators=50;, score=-0.277 total time=26.4min
# [CV 6/10; 12/12] START bootstrap=False, max_depth=12, n_estimators=50...........
# [CV 6/10; 12/12] END bootstrap=False, max_depth=12, n_estimators=50;, score=-0.409 total time=28.1min
# [CV 7/10; 12/12] START bootstrap=False, max_depth=12, n_estimators=50...........
# [CV 7/10; 12/12] END bootstrap=False, max_depth=12, n_estimators=50;, score=-0.326 total time=27.7min
# [CV 8/10; 12/12] START bootstrap=False, max_depth=12, n_estimators=50...........
# [CV 8/10; 12/12] END bootstrap=False, max_depth=12, n_estimators=50;, score=-0.382 total time=26.7min
# [CV 9/10; 12/12] START bootstrap=False, max_depth=12, n_estimators=50...........
# [CV 9/10; 12/12] END bootstrap=False, max_depth=12, n_estimators=50;, score=-0.422 total time=26.7min
# [CV 10/10; 12/12] START bootstrap=False, max_depth=12, n_estimators=50..........
# [CV 10/10; 12/12] END bootstrap=False, max_depth=12, n_estimators=50;, score=-0.441 total time=26.3min
# GridSearchCV(cv=10, estimator=RandomForestRegressor(),
#              param_grid={'bootstrap': [True, False], 'max_depth': [2, 6, 12],
#                          'n_estimators': [5, 50]},
#              scoring='neg_mean_squared_error', verbose=10)

# %%
print("GridSearch results:")
grid_search.cv_results_
# Out:
# GridSearch results:
# {'mean_fit_time': array([  25.93389876,  247.11600022,   65.12240374,  644.75568738,
#          101.87934301, 1021.94686739,   34.75123045,  343.92089531,
#           97.00566423,  961.96774209,  156.36534138, 1599.17191017]),
#  'std_fit_time': array([ 0.26509685,  8.92303769,  0.59417618,  5.8228937 ,  0.49918044,
#          5.61983259,  0.39749035,  1.24517403,  0.75179426,  5.27321824,
#          0.83007246, 39.01214001]),
#  'mean_score_time': array([0.03386769, 0.22660906, 0.06175754, 0.51004894, 0.12733037,
#         1.16862841, 0.03041189, 0.21382775, 0.06037731, 0.51408701,
#         0.12608624, 1.17540734]),
#  'std_score_time': array([0.00097734, 0.01324965, 0.00122357, 0.01153862, 0.00394691,
#         0.03947756, 0.00094273, 0.0057709 , 0.001409  , 0.00977595,
#         0.00378195, 0.0468983 ]),
#  'param_bootstrap': masked_array(data=[True, True, True, True, True, True, False, False,
#                     False, False, False, False],
#               mask=[False, False, False, False, False, False, False, False,
#                     False, False, False, False],
#         fill_value='?',
#              dtype=object),
#  'param_max_depth': masked_array(data=[2, 2, 6, 6, 12, 12, 2, 2, 6, 6, 12, 12],
#               mask=[False, False, False, False, False, False, False, False,
#                     False, False, False, False],
#         fill_value='?',
#              dtype=object),
#  'param_n_estimators': masked_array(data=[5, 50, 5, 50, 5, 50, 5, 50, 5, 50, 5, 50],
#               mask=[False, False, False, False, False, False, False, False,
#                     False, False, False, False],
#         fill_value='?',
#              dtype=object),
#  'params': [{'bootstrap': True, 'max_depth': 2, 'n_estimators': 5},
#   {'bootstrap': True, 'max_depth': 2, 'n_estimators': 50},
#   {'bootstrap': True, 'max_depth': 6, 'n_estimators': 5},
#   {'bootstrap': True, 'max_depth': 6, 'n_estimators': 50},
#   {'bootstrap': True, 'max_depth': 12, 'n_estimators': 5},
#   {'bootstrap': True, 'max_depth': 12, 'n_estimators': 50},
#   {'bootstrap': False, 'max_depth': 2, 'n_estimators': 5},
#   {'bootstrap': False, 'max_depth': 2, 'n_estimators': 50},
#   {'bootstrap': False, 'max_depth': 6, 'n_estimators': 5},
#   {'bootstrap': False, 'max_depth': 6, 'n_estimators': 50},
#   {'bootstrap': False, 'max_depth': 12, 'n_estimators': 5},
#   {'bootstrap': False, 'max_depth': 12, 'n_estimators': 50}],
#  'split0_test_score': array([-0.98593808, -0.98597409, -0.67678266, -0.67784838, -0.42351909,
#         -0.41911005, -0.98598635, -0.98598635, -0.69184084, -0.69184084,
#         -0.44842109, -0.44842142]),
#  'split1_test_score': array([-0.77713566, -0.77713307, -0.49294806, -0.49539128, -0.28497978,
#         -0.28323413, -0.77712753, -0.77712753, -0.50405063, -0.50405063,
#         -0.30611653, -0.30614007]),
#  'split2_test_score': array([-0.66275135, -0.66289301, -0.34893513, -0.34527081, -0.20155781,
#         -0.20027452, -0.66293438, -0.66293438, -0.36399895, -0.36399895,
#         -0.21383155, -0.21383134]),
#  'split3_test_score': array([-0.60684089, -0.60603301, -0.36514364, -0.35970954, -0.2112719 ,
#         -0.20723852, -0.60606648, -0.60606648, -0.37019043, -0.37019043,
#         -0.2204111 , -0.22041171]),
#  'split4_test_score': array([-0.72812621, -0.72813121, -0.44289894, -0.442234  , -0.26500788,
#         -0.26038143, -0.72811244, -0.72811244, -0.44825577, -0.44825577,
#         -0.27660558, -0.27658299]),
#  'split5_test_score': array([-1.01115453, -1.01113945, -0.65027112, -0.6416683 , -0.37374454,
#         -0.36937593, -1.01115791, -1.01115791, -0.66583876, -0.66583876,
#         -0.40899431, -0.40909671]),
#  'split6_test_score': array([-0.7611278 , -0.7611486 , -0.49286659, -0.49853744, -0.30441062,
#         -0.30524281, -0.76116202, -0.76116202, -0.50729845, -0.50729845,
#         -0.32552434, -0.32553334]),
#  'split7_test_score': array([-0.9195058 , -0.91952124, -0.60689691, -0.60781876, -0.35774536,
#         -0.34923888, -0.91950891, -0.91950891, -0.6239811 , -0.6239811 ,
#         -0.38240215, -0.38232586]),
#  'split8_test_score': array([-0.96382934, -0.96379336, -0.64712512, -0.65283093, -0.38863213,
#         -0.37760541, -0.96380869, -0.96380869, -0.6742166 , -0.6742166 ,
#         -0.42247954, -0.42245056]),
#  'split9_test_score': array([-0.94483401, -0.94491381, -0.65410483, -0.64917426, -0.40804598,
#         -0.40219638, -0.9449031 , -0.9449031 , -0.67155794, -0.67155794,
#         -0.44142583, -0.44099022]),
#  'mean_test_score': array([-0.83612437, -0.83606808, -0.5377973 , -0.53704837, -0.32189151,
#         -0.31738981, -0.83607678, -0.83607678, -0.55212295, -0.55212295,
#         -0.3446212 , -0.34457842]),
#  'std_test_score': array([0.13840353, 0.13852427, 0.11863228, 0.11924433, 0.07602632,
#         0.07436088, 0.138518  , 0.138518  , 0.12263205, 0.12263205,
#         0.08413458, 0.08408682]),
#  'rank_test_score': array([12,  9,  6,  5,  2,  1, 10, 10,  7,  8,  4,  3], dtype=int32)}

# %%
with open("../grids/grid_search_random_forest_01.pkl", mode="wb") as f:
    pickle.dump(grid_search, f)

# %%
best_regressor = grid_search.best_estimator_

# %%
print("Best regressor", best_regressor)
# Out:
# Best regressor RandomForestRegressor(max_depth=12, n_estimators=50)

# %%
with open("../models/model_random_forest_01.pkl", mode="wb") as f:
    pickle.dump(best_regressor, f)

# %%
y_hat = best_regressor.predict(X)

# %%
r2 = r2_score(y, y_hat)
mse = mean_squared_error(y, y_hat)

print(f"R2 Score: {r2:.3f}")
print(f"MSE: {mse:.3f}")
# Out:
# R2 Score: 0.694
# MSE: 0.306
