# %%
import pandas as pd
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv("../data/df_clean.csv", low_memory=False, index_col=0)

# %%
df.sample(5)
# Out:
#                                  smiles  homolumogap  number_of_atoms  \
# 2466047  Cc1ccc2c(c1)c(C(=N)S)c([nH]2)C     5.031385               26
# 324592     OC[C@@H]1CC[C@](C1)(C)C(=O)O     7.469525               25
# 1512278      OC[C@H](c1sccc1C)Nc1ccccc1     5.006895               31
# 2444417           OC(=N)CNc1ccc(cc1N)Cl     5.532075               23
# 2346479        CSCCCNC[C@@H](c1ccccc1)O     5.191932               34
#
#          number_of_bonds  number_of_heavy_bonds  number_of_heavy_atoms  \
# 2466047               27                     15                     14
# 324592                25                     11                     11
# 1512278               32                     17                     16
# 2444417               23                     13                     13
# 2346479               34                     15                     15
#
#          exact_mol_weight  average_mol_weight  heavy_mol_weight  \
# ...

# %%
test_rate = 0.1

df_train, df_test = train_test_split(df, test_size=test_rate, random_state=2907)

# %%
print("df_train shape", df_train.shape)
df_train = df_train.sort_index()
df_train.head(5)
# Out:
# df_train shape (3104579, 28)
#                                   smiles  homolumogap  number_of_atoms  \
# 0  O=C1[N]c2ccncc2[CH][C@@H]1c1ccc(cc1)C     3.047675               30
# 1          COc1cc(OC)ccc1/C=C/N(C(=O)C)C     4.410966               34
# 2            C=CCN(C(=O)C)/C=C/c1ccccc1C     4.639541               33
# 3            C=CCN(C(=O)C)/C=C/c1ccccc1F     4.492600               30
# 4           C=CCN(C(=O)C)/C=C/c1ccccc1Cl     4.612330               30
#
#    number_of_bonds  number_of_heavy_bonds  number_of_heavy_atoms  \
# 0               32                     20                     18
# 1               34                     17                     17
# 2               33                     16                     16
# 3               30                     16                     16
# 4               30                     16                     16
#
#    exact_mol_weight  average_mol_weight  heavy_mol_weight  \
# ...

# %%
print("df_test shape", df_test.shape)
df_test = df_test.sort_index()
df_test.head(5)
# Out:
# df_test shape (344954, 28)
#                                       smiles  homolumogap  number_of_atoms  \
# 21     O[C@@H]1CCN(C[C@H]1O)[C@H](c1ccccc1)C     5.994668               35
# 26             Fc1ccc(cc1)NC[C@H]1N=NC(=N1)S     2.955156               24
# 44             COC(=O)C[C@H](C(=C)C)CC(OC)OC     6.759308               35
# 46    ClC[C@@H]1[C@H]2CC[C@@H]([C@@H]1CCl)C2     7.929398               25
# 57  OC[C@H]1OC(O[C@@H]1[C@@H](OC(=O)C)C)(C)C     7.099450               33
#
#     number_of_bonds  number_of_heavy_bonds  number_of_heavy_atoms  \
# 21               36                     17                     16
# 26               25                     16                     15
# 44               34                     14                     15
# 46               26                     12                     11
# 57               33                     15                     15
#
#     exact_mol_weight  average_mol_weight  heavy_mol_weight  \
# ...

# %%
df_train.to_csv("../data/train.csv", index=False)
df_test.to_csv("../data/test.csv", index=False)

# %%
import pandas as pd
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv("../data/df_clean.csv", low_memory=False, index_col=0)

# %%
df.sample(5)
# Out:
#                                  smiles  homolumogap  number_of_atoms  \
# 2466047  Cc1ccc2c(c1)c(C(=N)S)c([nH]2)C     5.031385               26
# 324592     OC[C@@H]1CC[C@](C1)(C)C(=O)O     7.469525               25
# 1512278      OC[C@H](c1sccc1C)Nc1ccccc1     5.006895               31
# 2444417           OC(=N)CNc1ccc(cc1N)Cl     5.532075               23
# 2346479        CSCCCNC[C@@H](c1ccccc1)O     5.191932               34
#
#          number_of_bonds  number_of_heavy_bonds  number_of_heavy_atoms  \
# 2466047               27                     15                     14
# 324592                25                     11                     11
# 1512278               32                     17                     16
# 2444417               23                     13                     13
# 2346479               34                     15                     15
#
#          exact_mol_weight  average_mol_weight  heavy_mol_weight  \
# ...

# %%
test_rate = 0.1

df_train, df_test = train_test_split(df, test_size=test_rate, random_state=2907)

# %%
print("df_train shape", df_train.shape)
df_train = df_train.sort_index()
df_train.head(5)
# Out:
# df_train shape (3104579, 28)
#                                   smiles  homolumogap  number_of_atoms  \
# 0  O=C1[N]c2ccncc2[CH][C@@H]1c1ccc(cc1)C     3.047675               30
# 1          COc1cc(OC)ccc1/C=C/N(C(=O)C)C     4.410966               34
# 2            C=CCN(C(=O)C)/C=C/c1ccccc1C     4.639541               33
# 3            C=CCN(C(=O)C)/C=C/c1ccccc1F     4.492600               30
# 4           C=CCN(C(=O)C)/C=C/c1ccccc1Cl     4.612330               30
#
#    number_of_bonds  number_of_heavy_bonds  number_of_heavy_atoms  \
# 0               32                     20                     18
# 1               34                     17                     17
# 2               33                     16                     16
# 3               30                     16                     16
# 4               30                     16                     16
#
#    exact_mol_weight  average_mol_weight  heavy_mol_weight  \
# ...

# %%
print("df_test shape", df_test.shape)
df_test = df_test.sort_index()
df_test.head(5)
# Out:
# df_test shape (344954, 28)
#                                       smiles  homolumogap  number_of_atoms  \
# 21     O[C@@H]1CCN(C[C@H]1O)[C@H](c1ccccc1)C     5.994668               35
# 26             Fc1ccc(cc1)NC[C@H]1N=NC(=N1)S     2.955156               24
# 44             COC(=O)C[C@H](C(=C)C)CC(OC)OC     6.759308               35
# 46    ClC[C@@H]1[C@H]2CC[C@@H]([C@@H]1CCl)C2     7.929398               25
# 57  OC[C@H]1OC(O[C@@H]1[C@@H](OC(=O)C)C)(C)C     7.099450               33
#
#     number_of_bonds  number_of_heavy_bonds  number_of_heavy_atoms  \
# 21               36                     17                     16
# 26               25                     16                     15
# 44               34                     14                     15
# 46               26                     12                     11
# 57               33                     15                     15
#
#     exact_mol_weight  average_mol_weight  heavy_mol_weight  \
# ...

# %%
df_train.to_csv("../data/train.csv", index=False)
df_test.to_csv("../data/test.csv", index=False)
