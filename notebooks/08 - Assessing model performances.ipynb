# %% [markdown]
# ## Imports

# %%
import os
import pickle

from tqdm.notebook import tqdm
import numpy as np
import pandas as pd
pd.options.display.width = 0

from tensorflow.keras.layers import (
    Dense,
    Dropout,
)
from tensorflow.keras.models import Sequential

from sklearn.metrics import mean_squared_error, mean_absolute_error

# %% [markdown]
# ## Grid search models comparison

# %% [markdown]
# ### Import dumped grids

# %%
grids = [grid for grid in os.listdir('../grids') if 'grid_search' in grid]
grids
# Out:
# ['grid_search_decision_tree_regressor_01.pkl',
#  'grid_search_gradient_boosting_01.pkl',
#  'grid_search_linear_regressor_01.pkl',
#  'grid_search_neural_net_02.pkl',
#  'grid_search_random_forest_01.pkl',
#  'grid_search_svm_02.pkl']

# %% [markdown]
# ### Load other necessary files

# %%
X = np.load("../data/X_train_scaled.npy", allow_pickle=True)
y = np.load("../data/y_train_scaled.npy", allow_pickle=True)

def create_model(n_neurons, dropout_rate, input_shape=(X.shape[1], )):
    model = Sequential()
    model.add(Dense(n_neurons, activation="relu", input_shape=input_shape))
    if dropout_rate > 0:
        model.add(Dropout(dropout_rate))
    model.add(Dense(n_neurons, activation="relu"))
    if dropout_rate > 0:
        model.add(Dropout(dropout_rate))
    model.add(Dense(1, activation="linear"))
    model.compile(optimizer="adam", loss="mse")
    return model

# %% [markdown]
# ### Create comparison DataFrame

# %%
df_grid = pd.DataFrame()

for grid in grids:
    model_type = grid[grid.index("_", 8)+1:grid.rindex("_")]
    with open(f"../grids/{grid}", mode="rb") as f:
        pkl = pickle.load(f)
        gdf = pd.DataFrame.from_dict(pkl.cv_results_)[
            ["params", "mean_test_score", "std_test_score"]
        ]
        gdf["model_type"] = model_type
        df_grid = df_grid.append(
            gdf,
            ignore_index=True
        )

df_grid = df_grid.sort_values(
    "mean_test_score",
    ascending=False
).reset_index(drop=True)

print("All models")
df_grid
# Out:
# All models
#                                                params  mean_test_score  \
# 0                {'dropout_rate': 0, 'n_neurons': 64}        -0.209054
# 1                {'dropout_rate': 0, 'n_neurons': 32}        -0.229017
# 2              {'dropout_rate': 0.3, 'n_neurons': 64}        -0.261277
# 3              {'dropout_rate': 0.3, 'n_neurons': 32}        -0.286353
# 4   {'bootstrap': True, 'max_depth': 12, 'n_estima...        -0.317390
# 5   {'bootstrap': True, 'max_depth': 12, 'n_estima...        -0.321892
# 6   {'bootstrap': False, 'max_depth': 12, 'n_estim...        -0.344578
# 7   {'bootstrap': False, 'max_depth': 12, 'n_estim...        -0.344621
# 8               {'max_depth': 12, 'splitter': 'best'}        -0.344641
# 9                                                  {}        -0.388943
# 10            {'max_depth': 12, 'splitter': 'random'}        -0.420922
# 11  {'learning_rate': 0.1, 'n_estimators': 50, 'su...        -0.450435
# 12  {'learning_rate': 0.1, 'n_estimators': 50, 'su...        -0.450961
# 13  {'bootstrap': True, 'max_depth': 6, 'n_estimat...        -0.537048
# 14  {'bootstrap': True, 'max_depth': 6, 'n_estimat...        -0.537797
# 15  {'learning_rate': 0.05, 'n_estimators': 50, 's...        -0.552082
# 16  {'bootstrap': False, 'max_depth': 6, 'n_estima...        -0.552123
# 17               {'max_depth': 6, 'splitter': 'best'}        -0.552123
# 18  {'bootstrap': False, 'max_depth': 6, 'n_estima...        -0.552123
# 19  {'learning_rate': 0.05, 'n_estimators': 50, 's...        -0.552885
# 20                             {'C': 1, 'gamma': 0.8}        -0.562424
# 21                           {'C': 100, 'gamma': 0.8}        -0.567231
# 22                             {'C': 100, 'gamma': 1}        -0.596168
# 23                               {'C': 1, 'gamma': 1}        -0.602217
# 24             {'max_depth': 6, 'splitter': 'random'}        -0.689717
# 25  {'learning_rate': 0.1, 'n_estimators': 5, 'sub...        -0.812757
# 26  {'learning_rate': 0.1, 'n_estimators': 5, 'sub...        -0.813111
# 27  {'bootstrap': True, 'max_depth': 2, 'n_estimat...        -0.836068
# 28               {'max_depth': 2, 'splitter': 'best'}        -0.836077
# 29  {'bootstrap': False, 'max_depth': 2, 'n_estima...        -0.836077
# 30  {'bootstrap': False, 'max_depth': 2, 'n_estima...        -0.836077
# 31  {'bootstrap': True, 'max_depth': 2, 'n_estimat...        -0.836124
# 32  {'learning_rate': 0.05, 'n_estimators': 5, 'su...        -0.897862
# 33  {'learning_rate': 0.05, 'n_estimators': 5, 'su...        -0.898193
# 34             {'max_depth': 2, 'splitter': 'random'}        -0.910961
#
#     std_test_score               model_type
# 0         0.047653               neural_net
# 1         0.048251               neural_net
# 2         0.048857               neural_net
# 3         0.051733               neural_net
# 4         0.074361            random_forest
# 5         0.076026            random_forest
# 6         0.084087            random_forest
# 7         0.084135            random_forest
# 8         0.084111  decision_tree_regressor
# 9         0.065095         linear_regressor
# 10        0.089476  decision_tree_regressor
# 11        0.083229        gradient_boosting
# 12        0.083613        gradient_boosting
# 13        0.119244            random_forest
# 14        0.118632            random_forest
# 15        0.102831        gradient_boosting
# 16        0.122632            random_forest
# 17        0.122632  decision_tree_regressor
# 18        0.122632            random_forest
# 19        0.103418        gradient_boosting
# 20        0.025804                      svm
# 21        0.025989                      svm
# 22        0.025587                      svm
# 23        0.027345                      svm
# 24        0.130057  decision_tree_regressor
# 25        0.125674        gradient_boosting
# 26        0.125373        gradient_boosting
# 27        0.138524            random_forest
# 28        0.138518  decision_tree_regressor
# 29        0.138518            random_forest
# 30        0.138518            random_forest
# 31        0.138404            random_forest
# 32        0.126136        gradient_boosting
# 33        0.126180        gradient_boosting
# 34        0.117054  decision_tree_regressor

# %%
print("Best models")
df_grid.drop_duplicates('model_type')
# Out:
# Best models
#                                                params  mean_test_score  \
# 0                {'dropout_rate': 0, 'n_neurons': 64}        -0.209054
# 4   {'bootstrap': True, 'max_depth': 12, 'n_estima...        -0.317390
# 8               {'max_depth': 12, 'splitter': 'best'}        -0.344641
# 9                                                  {}        -0.388943
# 11  {'learning_rate': 0.1, 'n_estimators': 50, 'su...        -0.450435
# 20                             {'C': 1, 'gamma': 0.8}        -0.562424
#
#     std_test_score               model_type
# 0         0.047653               neural_net
# 4         0.074361            random_forest
# 8         0.084111  decision_tree_regressor
# 9         0.065095         linear_regressor
# 11        0.083229        gradient_boosting
# 20        0.025804                      svm

# %%
with open("../scalers/X_scaler.pkl", "rb") as f:
    X_scaler = pickle.load(f)

with open("../scalers/y_scaler.pkl", "rb") as f:
    y_scaler = pickle.load(f)

# %%
df_test = pd.read_csv("../data/test.csv")

X_test = X_scaler.transform(
    df_test.drop(["smiles", "homolumogap"], axis=1).to_numpy()
)
y_test = y_scaler.transform(
    df_test[["homolumogap"]].to_numpy()
)

# %%
df_test_result = pd.DataFrame(columns=["model_type", "mse", "mae"])

pbar = tqdm(grids)

for grid in pbar:
    model_type = grid[grid.index("_", 8)+1:grid.rindex("_")]
    pbar.set_description(f"Predicting with {model_type}...")
    
    with open(f"../grids/{grid}", mode="rb") as f:
        pkl = pickle.load(f)
    model = pkl.best_estimator_
    y_hat = model.predict(X_test)
    mse = mean_squared_error(y_test, y_hat)
    mae = mean_absolute_error(y_test, y_hat)
    df_test_result = df_test_result.append(
        {
            "model_type": model_type,
            "mse": mse,
            "mae": mae,
        },
        ignore_index=True
    )
# Out:
#   0%|          | 0/6 [00:00<?, ?it/s]
# WARNING:tensorflow:Unresolved object in checkpoint: (root).__call__
# WARNING:tensorflow:Unresolved object in checkpoint: (root).call_and_return_all_conditional_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._default_save_signature
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.__call__
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.call_and_return_all_conditional_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-1.__call__
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-1.call_and_return_all_conditional_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-2.__call__
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-2.call_and_return_all_conditional_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root).signatures.serving_default
# WARNING:tensorflow:A checkpoint was restored (e.g. tf.train.Checkpoint.restore or tf.keras.Model.load_weights) but not all checkpointed values were used. See above for specific issues. Use expect_partial() on the load status object, e.g. tf.train.Checkpoint.restore(...).expect_partial(), to silence these warnings, or use assert_consumed() to make the check explicit. See https://www.tensorflow.org/guide/checkpoint#loading_mechanics for details.
# 674/674 [==============================] - 1s 798us/step
# WARNING:tensorflow:Unresolved object in checkpoint: (root).__call__
# WARNING:tensorflow:Unresolved object in checkpoint: (root).call_and_return_all_conditional_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._default_save_signature
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.__call__
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.call_and_return_all_conditional_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-1.__call__
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-1.call_and_return_all_conditional_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-2.__call__
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-2.call_and_return_all_conditional_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root).signatures.serving_default
# WARNING:tensorflow:A checkpoint was restored (e.g. tf.train.Checkpoint.restore or tf.keras.Model.load_weights) but not all checkpointed values were used. See above for specific issues. Use expect_partial() on the load status object, e.g. tf.train.Checkpoint.restore(...).expect_partial(), to silence these warnings, or use assert_consumed() to make the check explicit. See https://www.tensorflow.org/guide/checkpoint#loading_mechanics for details.
# 642/674 [===========================>..] - ETA: 0sWARNING:tensorflow:Unresolved object in checkpoint: (root).__call__
# WARNING:tensorflow:Unresolved object in checkpoint: (root).call_and_return_all_conditional_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._default_save_signature
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.__call__
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.call_and_return_all_conditional_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-1.__call__
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-1.call_and_return_all_conditional_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-2.__call__
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-2.call_and_return_all_conditional_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root).signatures.serving_default
# WARNING:tensorflow:A checkpoint was restored (e.g. tf.train.Checkpoint.restore or tf.keras.Model.load_weights) but not all checkpointed values were used. See above for specific issues. Use expect_partial() on the load status object, e.g. tf.train.Checkpoint.restore(...).expect_partial(), to silence these warnings, or use assert_consumed() to make the check explicit. See https://www.tensorflow.org/guide/checkpoint#loading_mechanics for details.
# 585/674 [=========================>....] - ETA: 0sWARNING:tensorflow:Unresolved object in checkpoint: (root).__call__
# WARNING:tensorflow:Unresolved object in checkpoint: (root).call_and_return_all_conditional_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._default_save_signature
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.__call__
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.call_and_return_all_conditional_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-1.__call__
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-1.call_and_return_all_conditional_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-2.__call__
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-2.call_and_return_all_conditional_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root).signatures.serving_default
# WARNING:tensorflow:A checkpoint was restored (e.g. tf.train.Checkpoint.restore or tf.keras.Model.load_weights) but not all checkpointed values were used. See above for specific issues. Use expect_partial() on the load status object, e.g. tf.train.Checkpoint.restore(...).expect_partial(), to silence these warnings, or use assert_consumed() to make the check explicit. See https://www.tensorflow.org/guide/checkpoint#loading_mechanics for details.
# 549/674 [=======================>......] - ETA: 0sWARNING:tensorflow:Unresolved object in checkpoint: (root).__call__
# WARNING:tensorflow:Unresolved object in checkpoint: (root).call_and_return_all_conditional_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._default_save_signature
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.__call__
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.call_and_return_all_conditional_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-1.__call__
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-1.call_and_return_all_conditional_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-2.__call__
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-2.call_and_return_all_conditional_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root).signatures.serving_default
# WARNING:tensorflow:A checkpoint was restored (e.g. tf.train.Checkpoint.restore or tf.keras.Model.load_weights) but not all checkpointed values were used. See above for specific issues. Use expect_partial() on the load status object, e.g. tf.train.Checkpoint.restore(...).expect_partial(), to silence these warnings, or use assert_consumed() to make the check explicit. See https://www.tensorflow.org/guide/checkpoint#loading_mechanics for details.
# 497/674 [=====================>........] - ETA: 0sWARNING:tensorflow:Unresolved object in checkpoint: (root).__call__
# WARNING:tensorflow:Unresolved object in checkpoint: (root).call_and_return_all_conditional_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._default_save_signature
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.__call__
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.call_and_return_all_conditional_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-1.__call__
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-1.call_and_return_all_conditional_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-2.__call__
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-2.call_and_return_all_conditional_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root).signatures.serving_default
# WARNING:tensorflow:A checkpoint was restored (e.g. tf.train.Checkpoint.restore or tf.keras.Model.load_weights) but not all checkpointed values were used. See above for specific issues. Use expect_partial() on the load status object, e.g. tf.train.Checkpoint.restore(...).expect_partial(), to silence these warnings, or use assert_consumed() to make the check explicit. See https://www.tensorflow.org/guide/checkpoint#loading_mechanics for details.
# 426/674 [=================>............] - ETA: 0sWARNING:tensorflow:Unresolved object in checkpoint: (root).__call__
# WARNING:tensorflow:Unresolved object in checkpoint: (root).call_and_return_all_conditional_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._default_save_signature
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.__call__
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.call_and_return_all_conditional_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-1.__call__
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-1.call_and_return_all_conditional_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-2.__call__
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-2.call_and_return_all_conditional_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root).signatures.serving_default
# WARNING:tensorflow:A checkpoint was restored (e.g. tf.train.Checkpoint.restore or tf.keras.Model.load_weights) but not all checkpointed values were used. See above for specific issues. Use expect_partial() on the load status object, e.g. tf.train.Checkpoint.restore(...).expect_partial(), to silence these warnings, or use assert_consumed() to make the check explicit. See https://www.tensorflow.org/guide/checkpoint#loading_mechanics for details.
# 356/674 [==============>...............] - ETA: 0sWARNING:tensorflow:Unresolved object in checkpoint: (root).__call__
# WARNING:tensorflow:Unresolved object in checkpoint: (root).call_and_return_all_conditional_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._default_save_signature
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.__call__
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.call_and_return_all_conditional_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-1.__call__
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-1.call_and_return_all_conditional_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-2.__call__
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-2.call_and_return_all_conditional_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root).signatures.serving_default
# WARNING:tensorflow:A checkpoint was restored (e.g. tf.train.Checkpoint.restore or tf.keras.Model.load_weights) but not all checkpointed values were used. See above for specific issues. Use expect_partial() on the load status object, e.g. tf.train.Checkpoint.restore(...).expect_partial(), to silence these warnings, or use assert_consumed() to make the check explicit. See https://www.tensorflow.org/guide/checkpoint#loading_mechanics for details.
# 283/674 [===========>..................] - ETA: 0sWARNING:tensorflow:Unresolved object in checkpoint: (root).__call__
# WARNING:tensorflow:Unresolved object in checkpoint: (root).call_and_return_all_conditional_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._default_save_signature
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.__call__
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.call_and_return_all_conditional_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-1.__call__
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-1.call_and_return_all_conditional_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-2.__call__
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-2.call_and_return_all_conditional_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root).signatures.serving_default
# WARNING:tensorflow:A checkpoint was restored (e.g. tf.train.Checkpoint.restore or tf.keras.Model.load_weights) but not all checkpointed values were used. See above for specific issues. Use expect_partial() on the load status object, e.g. tf.train.Checkpoint.restore(...).expect_partial(), to silence these warnings, or use assert_consumed() to make the check explicit. See https://www.tensorflow.org/guide/checkpoint#loading_mechanics for details.
# 216/674 [========>.....................] - ETA: 0sWARNING:tensorflow:Unresolved object in checkpoint: (root).__call__
# WARNING:tensorflow:Unresolved object in checkpoint: (root).call_and_return_all_conditional_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._default_save_signature
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.__call__
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.call_and_return_all_conditional_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-1.__call__
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-1.call_and_return_all_conditional_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-2.__call__
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-2.call_and_return_all_conditional_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root).signatures.serving_default
# WARNING:tensorflow:A checkpoint was restored (e.g. tf.train.Checkpoint.restore or tf.keras.Model.load_weights) but not all checkpointed values were used. See above for specific issues. Use expect_partial() on the load status object, e.g. tf.train.Checkpoint.restore(...).expect_partial(), to silence these warnings, or use assert_consumed() to make the check explicit. See https://www.tensorflow.org/guide/checkpoint#loading_mechanics for details.
# 143/674 [=====>........................] - ETA: 0sWARNING:tensorflow:Unresolved object in checkpoint: (root).__call__
# WARNING:tensorflow:Unresolved object in checkpoint: (root).call_and_return_all_conditional_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._default_save_signature
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.__call__
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.call_and_return_all_conditional_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-1.__call__
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-1.call_and_return_all_conditional_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-2.__call__
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-2.call_and_return_all_conditional_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root).signatures.serving_default
# WARNING:tensorflow:A checkpoint was restored (e.g. tf.train.Checkpoint.restore or tf.keras.Model.load_weights) but not all checkpointed values were used. See above for specific issues. Use expect_partial() on the load status object, e.g. tf.train.Checkpoint.restore(...).expect_partial(), to silence these warnings, or use assert_consumed() to make the check explicit. See https://www.tensorflow.org/guide/checkpoint#loading_mechanics for details.
#  71/674 [==>...........................] - ETA: 0s  WARNING:tensorflow:Unresolved object in checkpoint: (root).__call__
# WARNING:tensorflow:Unresolved object in checkpoint: (root).call_and_return_all_conditional_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._default_save_signature
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.__call__
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.call_and_return_all_conditional_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-1.__call__
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-1.call_and_return_all_conditional_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-2.__call__
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-2.call_and_return_all_conditional_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root).signatures.serving_default
# WARNING:tensorflow:A checkpoint was restored (e.g. tf.train.Checkpoint.restore or tf.keras.Model.load_weights) but not all checkpointed values were used. See above for specific issues. Use expect_partial() on the load status object, e.g. tf.train.Checkpoint.restore(...).expect_partial(), to silence these warnings, or use assert_consumed() to make the check explicit. See https://www.tensorflow.org/guide/checkpoint#loading_mechanics for details.
#   1/674 [..............................] - ETA: 6:12WARNING:tensorflow:Unresolved object in checkpoint: (root).__call__
# WARNING:tensorflow:Unresolved object in checkpoint: (root).call_and_return_all_conditional_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._default_save_signature
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.__call__
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.call_and_return_all_conditional_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-1.__call__
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-1.call_and_return_all_conditional_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-2.__call__
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-2.call_and_return_all_conditional_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root).signatures.serving_default
# WARNING:tensorflow:A checkpoint was restored (e.g. tf.train.Checkpoint.restore or tf.keras.Model.load_weights) but not all checkpointed values were used. See above for specific issues. Use expect_partial() on the load status object, e.g. tf.train.Checkpoint.restore(...).expect_partial(), to silence these warnings, or use assert_consumed() to make the check explicit. See https://www.tensorflow.org/guide/checkpoint#loading_mechanics for details.
# WARNING:tensorflow:Unresolved object in checkpoint: (root).__call__
# WARNING:tensorflow:Unresolved object in checkpoint: (root).call_and_return_all_conditional_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._default_save_signature
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.__call__
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.call_and_return_all_conditional_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-1.__call__
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-1.call_and_return_all_conditional_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-2.__call__
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-2.call_and_return_all_conditional_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root).signatures.serving_default
# WARNING:tensorflow:Unresolved object in checkpoint: (root).__call__
# WARNING:tensorflow:Unresolved object in checkpoint: (root).call_and_return_all_conditional_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._default_save_signature
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.__call__
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.call_and_return_all_conditional_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-1.__call__
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-1.call_and_return_all_conditional_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-2.__call__
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-2.call_and_return_all_conditional_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root).__call__
# WARNING:tensorflow:Unresolved object in checkpoint: (root).call_and_return_all_conditional_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._default_save_signature
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.__call__
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.call_and_return_all_conditional_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-1.__call__
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-1.call_and_return_all_conditional_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-2.__call__
# WARNING:tensorflow:Unresolved object in checkpoint: (root).__call__
# WARNING:tensorflow:Unresolved object in checkpoint: (root).call_and_return_all_conditional_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._default_save_signature
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.__call__
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.call_and_return_all_conditional_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-1.__call__
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-1.call_and_return_all_conditional_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root).__call__
# WARNING:tensorflow:Unresolved object in checkpoint: (root).call_and_return_all_conditional_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._default_save_signature
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.__call__
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.call_and_return_all_conditional_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-1.__call__
# WARNING:tensorflow:Unresolved object in checkpoint: (root).__call__
# WARNING:tensorflow:Unresolved object in checkpoint: (root).call_and_return_all_conditional_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._default_save_signature
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.__call__
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.call_and_return_all_conditional_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root).__call__
# WARNING:tensorflow:Unresolved object in checkpoint: (root).call_and_return_all_conditional_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._default_save_signature
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.__call__
# WARNING:tensorflow:Unresolved object in checkpoint: (root).__call__
# WARNING:tensorflow:Unresolved object in checkpoint: (root).call_and_return_all_conditional_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._default_save_signature
# WARNING:tensorflow:Unresolved object in checkpoint: (root).__call__
# WARNING:tensorflow:Unresolved object in checkpoint: (root).call_and_return_all_conditional_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root).__call__
# 526/674 [======================>.......] - ETA: 0s450/674 [===================>..........] - ETA: 0s375/674 [===============>..............] - ETA: 0s299/674 [============>.................] - ETA: 0s226/674 [=========>....................] - ETA: 0s148/674 [=====>........................] - ETA: 0s 74/674 [==>...........................] - ETA: 0s   1/674 [..............................] - ETA: 26sWARNING:tensorflow:Unresolved object in checkpoint: (root).__call__
# WARNING:tensorflow:Unresolved object in checkpoint: (root).call_and_return_all_conditional_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._default_save_signature
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.__call__
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.call_and_return_all_conditional_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-1.__call__
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-1.call_and_return_all_conditional_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-2.__call__
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-2.call_and_return_all_conditional_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root).signatures.serving_default
# WARNING:tensorflow:A checkpoint was restored (e.g. tf.train.Checkpoint.restore or tf.keras.Model.load_weights) but not all checkpointed values were used. See above for specific issues. Use expect_partial() on the load status object, e.g. tf.train.Checkpoint.restore(...).expect_partial(), to silence these warnings, or use assert_consumed() to make the check explicit. See https://www.tensorflow.org/guide/checkpoint#loading_mechanics for details.
# 456/674 [===================>..........] - ETA: 0sWARNING:tensorflow:Unresolved object in checkpoint: (root).__call__
# WARNING:tensorflow:Unresolved object in checkpoint: (root).call_and_return_all_conditional_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._default_save_signature
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.__call__
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.call_and_return_all_conditional_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-1.__call__
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-1.call_and_return_all_conditional_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-2.__call__
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-2.call_and_return_all_conditional_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root).signatures.serving_default
# WARNING:tensorflow:A checkpoint was restored (e.g. tf.train.Checkpoint.restore or tf.keras.Model.load_weights) but not all checkpointed values were used. See above for specific issues. Use expect_partial() on the load status object, e.g. tf.train.Checkpoint.restore(...).expect_partial(), to silence these warnings, or use assert_consumed() to make the check explicit. See https://www.tensorflow.org/guide/checkpoint#loading_mechanics for details.
# 390/674 [================>.............] - ETA: 0sWARNING:tensorflow:Unresolved object in checkpoint: (root).__call__
# WARNING:tensorflow:Unresolved object in checkpoint: (root).call_and_return_all_conditional_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._default_save_signature
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.__call__
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.call_and_return_all_conditional_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-1.__call__
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-1.call_and_return_all_conditional_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-2.__call__
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-2.call_and_return_all_conditional_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root).signatures.serving_default
# WARNING:tensorflow:A checkpoint was restored (e.g. tf.train.Checkpoint.restore or tf.keras.Model.load_weights) but not all checkpointed values were used. See above for specific issues. Use expect_partial() on the load status object, e.g. tf.train.Checkpoint.restore(...).expect_partial(), to silence these warnings, or use assert_consumed() to make the check explicit. See https://www.tensorflow.org/guide/checkpoint#loading_mechanics for details.
# 324/674 [=============>................] - ETA: 0sWARNING:tensorflow:Unresolved object in checkpoint: (root).__call__
# WARNING:tensorflow:Unresolved object in checkpoint: (root).call_and_return_all_conditional_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._default_save_signature
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.__call__
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.call_and_return_all_conditional_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-1.__call__
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-1.call_and_return_all_conditional_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-2.__call__
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-2.call_and_return_all_conditional_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root).signatures.serving_default
# WARNING:tensorflow:A checkpoint was restored (e.g. tf.train.Checkpoint.restore or tf.keras.Model.load_weights) but not all checkpointed values were used. See above for specific issues. Use expect_partial() on the load status object, e.g. tf.train.Checkpoint.restore(...).expect_partial(), to silence these warnings, or use assert_consumed() to make the check explicit. See https://www.tensorflow.org/guide/checkpoint#loading_mechanics for details.
# 257/674 [==========>...................] - ETA: 0sWARNING:tensorflow:Unresolved object in checkpoint: (root).__call__
# WARNING:tensorflow:Unresolved object in checkpoint: (root).call_and_return_all_conditional_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._default_save_signature
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.__call__
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.call_and_return_all_conditional_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-1.__call__
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-1.call_and_return_all_conditional_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-2.__call__
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-2.call_and_return_all_conditional_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root).signatures.serving_default
# WARNING:tensorflow:A checkpoint was restored (e.g. tf.train.Checkpoint.restore or tf.keras.Model.load_weights) but not all checkpointed values were used. See above for specific issues. Use expect_partial() on the load status object, e.g. tf.train.Checkpoint.restore(...).expect_partial(), to silence these warnings, or use assert_consumed() to make the check explicit. See https://www.tensorflow.org/guide/checkpoint#loading_mechanics for details.
# 197/674 [=======>......................] - ETA: 0sWARNING:tensorflow:Unresolved object in checkpoint: (root).__call__
# WARNING:tensorflow:Unresolved object in checkpoint: (root).call_and_return_all_conditional_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._default_save_signature
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.__call__
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.call_and_return_all_conditional_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-1.__call__
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-1.call_and_return_all_conditional_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-2.__call__
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-2.call_and_return_all_conditional_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root).signatures.serving_default
# WARNING:tensorflow:A checkpoint was restored (e.g. tf.train.Checkpoint.restore or tf.keras.Model.load_weights) but not all checkpointed values were used. See above for specific issues. Use expect_partial() on the load status object, e.g. tf.train.Checkpoint.restore(...).expect_partial(), to silence these warnings, or use assert_consumed() to make the check explicit. See https://www.tensorflow.org/guide/checkpoint#loading_mechanics for details.
# 131/674 [====>.........................] - ETA: 0sWARNING:tensorflow:Unresolved object in checkpoint: (root).__call__
# WARNING:tensorflow:Unresolved object in checkpoint: (root).call_and_return_all_conditional_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._default_save_signature
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.__call__
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.call_and_return_all_conditional_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-1.__call__
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-1.call_and_return_all_conditional_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-2.__call__
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-2.call_and_return_all_conditional_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root).signatures.serving_default
# WARNING:tensorflow:A checkpoint was restored (e.g. tf.train.Checkpoint.restore or tf.keras.Model.load_weights) but not all checkpointed values were used. See above for specific issues. Use expect_partial() on the load status object, e.g. tf.train.Checkpoint.restore(...).expect_partial(), to silence these warnings, or use assert_consumed() to make the check explicit. See https://www.tensorflow.org/guide/checkpoint#loading_mechanics for details.
#  68/674 [==>...........................] - ETA: 0s  WARNING:tensorflow:Unresolved object in checkpoint: (root).__call__
# WARNING:tensorflow:Unresolved object in checkpoint: (root).call_and_return_all_conditional_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._default_save_signature
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.__call__
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.call_and_return_all_conditional_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-1.__call__
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-1.call_and_return_all_conditional_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-2.__call__
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-2.call_and_return_all_conditional_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root).signatures.serving_default
# WARNING:tensorflow:A checkpoint was restored (e.g. tf.train.Checkpoint.restore or tf.keras.Model.load_weights) but not all checkpointed values were used. See above for specific issues. Use expect_partial() on the load status object, e.g. tf.train.Checkpoint.restore(...).expect_partial(), to silence these warnings, or use assert_consumed() to make the check explicit. See https://www.tensorflow.org/guide/checkpoint#loading_mechanics for details.
#   1/674 [..............................] - ETA: 6:22WARNING:tensorflow:Unresolved object in checkpoint: (root).__call__
# WARNING:tensorflow:Unresolved object in checkpoint: (root).call_and_return_all_conditional_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._default_save_signature
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.__call__
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.call_and_return_all_conditional_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-1.__call__
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-1.call_and_return_all_conditional_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-2.__call__
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-2.call_and_return_all_conditional_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root).signatures.serving_default
# WARNING:tensorflow:A checkpoint was restored (e.g. tf.train.Checkpoint.restore or tf.keras.Model.load_weights) but not all checkpointed values were used. See above for specific issues. Use expect_partial() on the load status object, e.g. tf.train.Checkpoint.restore(...).expect_partial(), to silence these warnings, or use assert_consumed() to make the check explicit. See https://www.tensorflow.org/guide/checkpoint#loading_mechanics for details.
# WARNING:tensorflow:Unresolved object in checkpoint: (root).__call__
# WARNING:tensorflow:Unresolved object in checkpoint: (root).call_and_return_all_conditional_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._default_save_signature
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.__call__
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.call_and_return_all_conditional_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-1.__call__
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-1.call_and_return_all_conditional_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-2.__call__
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-2.call_and_return_all_conditional_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root).signatures.serving_default
# WARNING:tensorflow:Unresolved object in checkpoint: (root).__call__
# WARNING:tensorflow:Unresolved object in checkpoint: (root).call_and_return_all_conditional_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._default_save_signature
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.__call__
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.call_and_return_all_conditional_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-1.__call__
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-1.call_and_return_all_conditional_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-2.__call__
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-2.call_and_return_all_conditional_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root).__call__
# WARNING:tensorflow:Unresolved object in checkpoint: (root).call_and_return_all_conditional_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._default_save_signature
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.__call__
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.call_and_return_all_conditional_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-1.__call__
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-1.call_and_return_all_conditional_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-2.__call__
# WARNING:tensorflow:Unresolved object in checkpoint: (root).__call__
# WARNING:tensorflow:Unresolved object in checkpoint: (root).call_and_return_all_conditional_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._default_save_signature
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.__call__
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.call_and_return_all_conditional_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-1.__call__
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-1.call_and_return_all_conditional_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root).__call__
# WARNING:tensorflow:Unresolved object in checkpoint: (root).call_and_return_all_conditional_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._default_save_signature
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.__call__
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.call_and_return_all_conditional_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-1.__call__
# WARNING:tensorflow:Unresolved object in checkpoint: (root).__call__
# WARNING:tensorflow:Unresolved object in checkpoint: (root).call_and_return_all_conditional_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._default_save_signature
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.__call__
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.call_and_return_all_conditional_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root).__call__
# WARNING:tensorflow:Unresolved object in checkpoint: (root).call_and_return_all_conditional_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._default_save_signature
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.__call__
# WARNING:tensorflow:Unresolved object in checkpoint: (root).__call__
# WARNING:tensorflow:Unresolved object in checkpoint: (root).call_and_return_all_conditional_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._default_save_signature
# WARNING:tensorflow:Unresolved object in checkpoint: (root).__call__
# WARNING:tensorflow:Unresolved object in checkpoint: (root).call_and_return_all_conditional_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root).__call__
# WARNING:tensorflow:Unresolved object in checkpoint: (root).__call__
# WARNING:tensorflow:Unresolved object in checkpoint: (root).call_and_return_all_conditional_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._default_save_signature
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.__call__
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.call_and_return_all_conditional_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-1.__call__
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-1.call_and_return_all_conditional_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-2.__call__
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-2.call_and_return_all_conditional_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root).signatures.serving_default
# WARNING:tensorflow:A checkpoint was restored (e.g. tf.train.Checkpoint.restore or tf.keras.Model.load_weights) but not all checkpointed values were used. See above for specific issues. Use expect_partial() on the load status object, e.g. tf.train.Checkpoint.restore(...).expect_partial(), to silence these warnings, or use assert_consumed() to make the check explicit. See https://www.tensorflow.org/guide/checkpoint#loading_mechanics for details.
# 467/674 [===================>..........] - ETA: 0sWARNING:tensorflow:Unresolved object in checkpoint: (root).__call__
# WARNING:tensorflow:Unresolved object in checkpoint: (root).call_and_return_all_conditional_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._default_save_signature
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.__call__
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.call_and_return_all_conditional_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-1.__call__
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-1.call_and_return_all_conditional_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-2.__call__
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-2.call_and_return_all_conditional_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root).signatures.serving_default
# WARNING:tensorflow:A checkpoint was restored (e.g. tf.train.Checkpoint.restore or tf.keras.Model.load_weights) but not all checkpointed values were used. See above for specific issues. Use expect_partial() on the load status object, e.g. tf.train.Checkpoint.restore(...).expect_partial(), to silence these warnings, or use assert_consumed() to make the check explicit. See https://www.tensorflow.org/guide/checkpoint#loading_mechanics for details.
# 400/674 [================>.............] - ETA: 0sWARNING:tensorflow:Unresolved object in checkpoint: (root).__call__
# WARNING:tensorflow:Unresolved object in checkpoint: (root).call_and_return_all_conditional_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._default_save_signature
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.__call__
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.call_and_return_all_conditional_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-1.__call__
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-1.call_and_return_all_conditional_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-2.__call__
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-2.call_and_return_all_conditional_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root).signatures.serving_default
# WARNING:tensorflow:A checkpoint was restored (e.g. tf.train.Checkpoint.restore or tf.keras.Model.load_weights) but not all checkpointed values were used. See above for specific issues. Use expect_partial() on the load status object, e.g. tf.train.Checkpoint.restore(...).expect_partial(), to silence these warnings, or use assert_consumed() to make the check explicit. See https://www.tensorflow.org/guide/checkpoint#loading_mechanics for details.
# 337/674 [==============>...............] - ETA: 0sWARNING:tensorflow:Unresolved object in checkpoint: (root).__call__
# WARNING:tensorflow:Unresolved object in checkpoint: (root).call_and_return_all_conditional_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._default_save_signature
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.__call__
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.call_and_return_all_conditional_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-1.__call__
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-1.call_and_return_all_conditional_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-2.__call__
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-2.call_and_return_all_conditional_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root).signatures.serving_default
# WARNING:tensorflow:A checkpoint was restored (e.g. tf.train.Checkpoint.restore or tf.keras.Model.load_weights) but not all checkpointed values were used. See above for specific issues. Use expect_partial() on the load status object, e.g. tf.train.Checkpoint.restore(...).expect_partial(), to silence these warnings, or use assert_consumed() to make the check explicit. See https://www.tensorflow.org/guide/checkpoint#loading_mechanics for details.
# 264/674 [==========>...................] - ETA: 0sWARNING:tensorflow:Unresolved object in checkpoint: (root).__call__
# WARNING:tensorflow:Unresolved object in checkpoint: (root).call_and_return_all_conditional_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._default_save_signature
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.__call__
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.call_and_return_all_conditional_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-1.__call__
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-1.call_and_return_all_conditional_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-2.__call__
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-2.call_and_return_all_conditional_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root).signatures.serving_default
# WARNING:tensorflow:A checkpoint was restored (e.g. tf.train.Checkpoint.restore or tf.keras.Model.load_weights) but not all checkpointed values were used. See above for specific issues. Use expect_partial() on the load status object, e.g. tf.train.Checkpoint.restore(...).expect_partial(), to silence these warnings, or use assert_consumed() to make the check explicit. See https://www.tensorflow.org/guide/checkpoint#loading_mechanics for details.
# 200/674 [=======>......................] - ETA: 0sWARNING:tensorflow:Unresolved object in checkpoint: (root).__call__
# WARNING:tensorflow:Unresolved object in checkpoint: (root).call_and_return_all_conditional_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._default_save_signature
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.__call__
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.call_and_return_all_conditional_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-1.__call__
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-1.call_and_return_all_conditional_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-2.__call__
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-2.call_and_return_all_conditional_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root).signatures.serving_default
# WARNING:tensorflow:A checkpoint was restored (e.g. tf.train.Checkpoint.restore or tf.keras.Model.load_weights) but not all checkpointed values were used. See above for specific issues. Use expect_partial() on the load status object, e.g. tf.train.Checkpoint.restore(...).expect_partial(), to silence these warnings, or use assert_consumed() to make the check explicit. See https://www.tensorflow.org/guide/checkpoint#loading_mechanics for details.
# 131/674 [====>.........................] - ETA: 0sWARNING:tensorflow:Unresolved object in checkpoint: (root).__call__
# WARNING:tensorflow:Unresolved object in checkpoint: (root).call_and_return_all_conditional_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._default_save_signature
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.__call__
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.call_and_return_all_conditional_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-1.__call__
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-1.call_and_return_all_conditional_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-2.__call__
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-2.call_and_return_all_conditional_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root).signatures.serving_default
# WARNING:tensorflow:A checkpoint was restored (e.g. tf.train.Checkpoint.restore or tf.keras.Model.load_weights) but not all checkpointed values were used. See above for specific issues. Use expect_partial() on the load status object, e.g. tf.train.Checkpoint.restore(...).expect_partial(), to silence these warnings, or use assert_consumed() to make the check explicit. See https://www.tensorflow.org/guide/checkpoint#loading_mechanics for details.
#  64/674 [=>............................] - ETA: 0s  WARNING:tensorflow:Unresolved object in checkpoint: (root).__call__
# WARNING:tensorflow:Unresolved object in checkpoint: (root).call_and_return_all_conditional_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._default_save_signature
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.__call__
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.call_and_return_all_conditional_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-1.__call__
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-1.call_and_return_all_conditional_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-2.__call__
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-2.call_and_return_all_conditional_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root).signatures.serving_default
# WARNING:tensorflow:A checkpoint was restored (e.g. tf.train.Checkpoint.restore or tf.keras.Model.load_weights) but not all checkpointed values were used. See above for specific issues. Use expect_partial() on the load status object, e.g. tf.train.Checkpoint.restore(...).expect_partial(), to silence these warnings, or use assert_consumed() to make the check explicit. See https://www.tensorflow.org/guide/checkpoint#loading_mechanics for details.
#   1/674 [..............................] - ETA: 6:07WARNING:tensorflow:Unresolved object in checkpoint: (root).__call__
# WARNING:tensorflow:Unresolved object in checkpoint: (root).call_and_return_all_conditional_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._default_save_signature
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.__call__
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.call_and_return_all_conditional_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-1.__call__
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-1.call_and_return_all_conditional_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-2.__call__
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-2.call_and_return_all_conditional_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root).signatures.serving_default
# WARNING:tensorflow:A checkpoint was restored (e.g. tf.train.Checkpoint.restore or tf.keras.Model.load_weights) but not all checkpointed values were used. See above for specific issues. Use expect_partial() on the load status object, e.g. tf.train.Checkpoint.restore(...).expect_partial(), to silence these warnings, or use assert_consumed() to make the check explicit. See https://www.tensorflow.org/guide/checkpoint#loading_mechanics for details.
# WARNING:tensorflow:Unresolved object in checkpoint: (root).__call__
# WARNING:tensorflow:Unresolved object in checkpoint: (root).call_and_return_all_conditional_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._default_save_signature
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.__call__
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.call_and_return_all_conditional_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-1.__call__
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-1.call_and_return_all_conditional_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-2.__call__
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-2.call_and_return_all_conditional_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root).signatures.serving_default
# WARNING:tensorflow:Unresolved object in checkpoint: (root).__call__
# WARNING:tensorflow:Unresolved object in checkpoint: (root).call_and_return_all_conditional_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._default_save_signature
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.__call__
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.call_and_return_all_conditional_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-1.__call__
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-1.call_and_return_all_conditional_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-2.__call__
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-2.call_and_return_all_conditional_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root).__call__
# WARNING:tensorflow:Unresolved object in checkpoint: (root).call_and_return_all_conditional_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._default_save_signature
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.__call__
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.call_and_return_all_conditional_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-1.__call__
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-1.call_and_return_all_conditional_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-2.__call__
# WARNING:tensorflow:Unresolved object in checkpoint: (root).__call__
# WARNING:tensorflow:Unresolved object in checkpoint: (root).call_and_return_all_conditional_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._default_save_signature
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.__call__
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.call_and_return_all_conditional_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-1.__call__
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-1.call_and_return_all_conditional_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root).__call__
# WARNING:tensorflow:Unresolved object in checkpoint: (root).call_and_return_all_conditional_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._default_save_signature
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.__call__
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.call_and_return_all_conditional_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-1.__call__
# WARNING:tensorflow:Unresolved object in checkpoint: (root).__call__
# WARNING:tensorflow:Unresolved object in checkpoint: (root).call_and_return_all_conditional_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._default_save_signature
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.__call__
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.call_and_return_all_conditional_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root).__call__
# WARNING:tensorflow:Unresolved object in checkpoint: (root).call_and_return_all_conditional_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._default_save_signature
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-0.__call__
# WARNING:tensorflow:Unresolved object in checkpoint: (root).__call__
# WARNING:tensorflow:Unresolved object in checkpoint: (root).call_and_return_all_conditional_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root)._default_save_signature
# WARNING:tensorflow:Unresolved object in checkpoint: (root).__call__
# WARNING:tensorflow:Unresolved object in checkpoint: (root).call_and_return_all_conditional_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root).__call__

# %%
df_test_result.sort_values(["mse", "mae"]).reset_index(drop=True)
# Out:
#                 model_type       mse       mae
# 0               neural_net  0.198305  0.327192
# 1            random_forest  0.311386  0.418187
# 2  decision_tree_regressor  0.333308  0.430803
# 3         linear_regressor  0.385191  0.477560
# 4        gradient_boosting  0.438995  0.509825
# 5                      svm  0.569116  0.551528
